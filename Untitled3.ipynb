# %% [markdown]
# name=input("Enter the name : ")
# print("welcome", name)

# %%
m="123"
print(m[::-1])
# Out:
# 321

# %%
k="rachana"
print(k[::-1])
# Out:
# anahcar

# %%
name="rachana"
def greet():
    print("Hello", name)
greet()
# Out:
# Hello rachana

# %%
game="running"
def run():
    print("In the morning i went for",  game)
run()
# Out:
# In the morning i went for running

# %%
def add(a,b):
    return a+b
print(add(10,20))
# Out:
# 30

# %%
def add(a,b,c=0):
    return a+b+c
print(add(20,40))
print(add(20,40,60))
# Out:
# 60
# 120

# %%
def multiplication(a,b,c=0):
  return a*b*c
print(multiplication(30,60))
print(multiplication(40,50,60))
# Out:
# 0
# 120000

# %%
def subtraction(a,b,c=0):
    return a-b-c
print(subtraction(999,777))
print(subtraction(777,666,567))
# Out:
# 222
# -456

# %%
def add(*numbers):
    print(sum(numbers))
add(55,77)
add(56,67,78)
add(45,56,78,89)
# Out:
# 132
# 201
# 268

# %%
def add(*numbers):
    print(sum(numbers))
add(10,20)
add(10,20,30)
add(10,20,30,40)
add(10,20,30,40,50)
# Out:
# 30
# 60
# 100
# 150

# %%
def students (*marks):
    print(sum(students)):
student(10,30)
student
