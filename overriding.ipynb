# %%
class Parent:
    def func(self):
        print("This function belongs to parent class")
        
class Child(Parent):
    def func1(self):
        print("this function belong to child class")
object=Child()
object.func1()
# Out:
# this function belong to child class
