# %%
name="rachana"
print(name.upper())
# Out:
# RACHANA

# %%
name="RACHANA"
print(name.lower())
# Out:
# rachana

# %%
name="rachana"
print(name.lower())
# Out:
# rachana

# %%
print("Hellow" * 8)
# Out:
# HellowHellowHellowHellowHellowHellowHellowHellow

# %%
name="rachana"
print(name[1:5])
# Out:
# acha

# %%
animal="tiger"
print(animal[1:2])
# Out:
# i

# %%
name="rachana"
email="rachanakada24@emil.com"
print(name,email)
# Out:
# rachana rachanakada24@emil.com

# %%
print(name)
print(email)
# Out:
# rachana
# rachanakada24@emil.com

# %%
k="I like Java"
print(k.replace("Java" , "Python"))
# Out:
# I like Python

# %%
k="anything something"
print(k.find("something"))
# Out:
# 9

# %%
name=input("Enter the name :")
print("welcome", name)
