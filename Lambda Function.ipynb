# %%
def square(x):
      return x*x
print(square(6))
# Out:
# 36

# %%
square=lambda x:x*x
print(square(3))
# Out:
# 9

# %%
multi=lambda a,b:a*b
print(multi(5,2))
# Out:
# 10

# %%
def multi(r,s):
    return r*s
print(multi(7,8))
# Out:
# 56

# %%
check=lambda num:"Even" if num%2==0 else"odd"
print(check(10))
# Out:
# Even

# %%
students=[("rachu",80),("harshu",90),("bhanu",75)]
result=sorted(students,key=lambda x:x[1])
print(result)
# Out:
# [('bhanu', 75), ('rachu', 80), ('harshu', 90)]

# %%
numbers=[1,2,3,4,5]
enter=list(map(lambda x:x*x,numbers))
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
k=[9,5,6,7,8]
result=list(filter(lambda num:num%2==0))
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 k=[9,5,6,7,8]
# ----> 2 result=list(filter(lambda num:num%2==0))
#       3 print(result)
#
# TypeError: filter expected 2 arguments, got 1

# %%
v=[4,5,6,7,8]
result=list(filter(lambda num:num%2==1))
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 v=[4,5,6,7,8]
# ----> 2 result=list(filter(lambda num:num%2==1))
#       3 print(result)
#
# TypeError: filter expected 2 arguments, got 1

# %%
from functool import reduce
y=[1,2,3,4,5]
result=reduce(lambda xy:x+y ,
