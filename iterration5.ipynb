# %%
name=["rachuuu","harshuu","siriiiii"]
print(name)
# Out:
# ['rachuuu', 'harshuu', 'siriiiii']

# %%
name=["rachana","raachu"]
it=iter(name)
print(next(it))
print(next(it))
# Out:
# rachana
# raachu

# %%
num=["20","40","60","00"]
it=iter(num)
print(next(it))
print(next(it))
print(next(it))
print(next(it))
# Out:
# 20
# 40
# 60
# 00

# %%
flowers=["rose","jasmine","lilly","lotus"]
it=iter(flowers)
print(next(it))
print(next(it))
print(next(it))
print(next(it))
# Out:
# rose
# jasmine
# lilly
# lotus

# %%
def numbers():
    yield 1
    yield 2
    yield 3
gen = numbers()
print(next(gen))
print(next(gen))
print(next(gen))
# Out:
# 1
# 2
# 3
