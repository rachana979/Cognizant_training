# %%
import pandas as pd     
orders=pd.Series(["Delivered","Cancelled","Delivered","Pending"])
print(orders.dtype)
orders=orders.astype("category")
print(orders.dtype)
# Out:
# object
# category

# %%
import pandas as pd
salary=[1000,2000,3000,4000]
new_salary=[]
for s in salary:
    new_salary.append(s*1.1)
print(new_salary)
# Out:
# [1100.0, 2200.0, 3300.0000000000005, 4400.0]

# %%
import numpy as np
salary=np.array([1000,2000,3000,4000,5000])
new_salary=salary*1.1
print(new_salary)
# Out:
# [1100. 2200. 3300. 4400. 5500.]

# %%
import numpy as np 
prize=np.array([1200,1300,1400,1500])
discount=prize*0.5
print(discount)
# Out:
# [600. 650. 700. 750.]

# %%
import pandas as pd
data=pd.Series(range(1,10))
sample=data.sample(5)
print(sample)
# Out:
# 0    1
# 8    9
# 4    5
# 1    2
# 6    7
# dtype: int64

# %%
sample=data.sample(frac=0.2)
print(sample)
# Out:
# 5    6
# 7    8
# dtype: int64

# %%
import numpy as np
salary=([50000,65000,34000,5600])
print(np.median(salary))
# Out:
# 42000.0

# %%
import numpy as np
salary=([23000,34000,67000,89000])
print(np.mean(salary))
# Out:
# 53250.0

# %%
from scipy import stats
data=[10,20,30,40,50,60,60]
print(stats.mode(data))
# Out:
# ModeResult(mode=np.int64(60), count=np.int64(2))

# %%
import numpy as np
salary=([2500,3400,5600,5400])
print(np.max(salary))
# Out:
# 5600

# %%
salary=([2500,3400,5600,5400])
print(np.min(salary))
# Out:
# 2500

# %%
salary=([2500,3400,5600,5400])
print(np.max(salary)-min(salary))
# Out:
# 3100

# %%
salary=([10,20,30,40,50])
print(np.var(salary))
# Out:
# 200.0

# %%
salary=([200,300,400,500,600])
print(np.std(salary))
# Out:
# 141.4213562373095

# %%
marks=([10,34,20,40,50,60])
print(np.min(marks))
print(np.max(marks))
print(np.max(marks)-min(marks))
print(np.mean(marks))
print(np.median(marks))
print(np.var(marks))
print(np.std(marks))
# Out:
# 10
# 60
# 50
# 35.666666666666664
# 37.0
# 287.2222222222222
# 16.94763175851488

# %%
import pandas as pd
student={
    "Name":["Ayubb","Ayan","Afrin"],
    "Marks":[100,95,80]
}
details=pd.DataFrame(student)
print(details.sample(2))
# Out:
#     Name  Marks
# 2  Afrin     80
# 1   Ayan     95

# %%
import pandas as pd 
student={
    "Name":["Varun","stya","soumii"],
    "Marks":[250,300,400]
}
details=pd.DataFrame(student)
details.sample(3,random_state=0)
# Out:
#      Name  Marks
# 2  soumii    400
# 1    stya    300
# 0   Varun    250

# %%
import numpy as np
salary=np.array([2300,4500,6007,3400])
bonus=salary+900
print(bonus)
# Out:
# [3200 5400 6907 4300]
