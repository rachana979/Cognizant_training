# %%
age=int(input("Enter the age"))
if age>18:
     raise Exception("you are not eligible for vote")
print("Eligible")
# Out:
# Enter the age 20
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 age=int(input("Enter the age"))
#       2 if age>18:
# ----> 3     raise Exception("you are not eligible for vote")
#       4 print("Eligible")
#
# Exception: you are not eligible for vote

# %%
marks=int(input("Enter the marks"))
if marks<=35:
    raise Exception("You are not pass")
print("You are pass")
# Out:
# Enter the marks 69
# You are pass

# %%
marks=int(input("Enter the marks"))
if marks<=35:
    raise Exception("You are not pass")
print("You are pass")
# Out:
# Enter the marks 29
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 marks=int(input("Enter the marks"))
#       2 if marks<=35:
# ----> 3     raise Exception("You are not pass")
#       4 print("You are pass")
#
# Exception: You are not pass

# %%
age=int(input("Enter the age"))
if age<=18:
    raise Exception("You are not eligible for vote")
print("Eligible")
