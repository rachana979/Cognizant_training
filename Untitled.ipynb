# %%
name="Rachana"
age=19
print(name)
print(age)
# Out:
# Rachana
# 19

# %%
class Car :
    colour="Red"
    brand="BMW"
    

    Car1=Car()
    print(car1.colour)
    print(car1.brand)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 class Car :
#       2     colour="Red"
#       3     brand="BMW"
#
# Cell In[6], line 6, in Car()
#       2 colour="Red"
#       3 brand="BMW"
# ----> 6 Car1=Car()
#       7 print(car1.colour)
#       8 print(car1.brand)
#
# NameError: name 'Car' is not defined

# %%
class Car :
    colour="Red"
    brand="BMW"
    

    Car1=Car()
    print(car1.colour)
    print(car1.brand)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 class Car :
#       2     colour="Red"
#       3     brand="BMW"
#
# Cell In[6], line 6, in Car()
#       2 colour="Red"
#       3 brand="BMW"
# ----> 6 Car1=Car()
#       7 print(car1.colour)
#       8 print(car1.brand)
#
# NameError: name 'Car' is not defined
