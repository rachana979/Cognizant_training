# %%
import pandas as pd
data={
    "Date":["2006-04-24","2006-12-14","2025-5-25","2026-10-12"]
}
result=pd.DataFrame(data)
result["Date"]=pd.to_datetime(result["Date"])
print(result)
# Out:
#         Date
# 0 2006-04-24
# 1 2006-12-14
# 2 2025-05-25
# 3 2026-10-12

# %%
result["Date"].dt.month
# Out:
# 0     4
# 1    12
# 2     5
# 3    10
# Name: Date, dtype: int32

# %%
result["Date"].dt.year
# Out:
# 0    2006
# 1    2006
# 2    2025
# 3    2026
# Name: Date, dtype: int32

# %%
result["Date"].dt.day
# Out:
# 0    24
# 1    14
# 2    25
# 3    12
# Name: Date, dtype: int32

# %%
result["Date"].dt.day_name()
# Out:
# 0      Monday
# 1    Thursday
# 2      Sunday
# 3      Monday
# Name: Date, dtype: object

# %%
pd.Timestamp.now()
# Out:
# Timestamp('2026-06-18 16:22:12.818570')

# %%
from datetime import datetime
date1=datetime(2006,4,24)
date2=datetime(2006,12,14)
print(date2-date1)
# Out:
# 234 days, 0:00:00
