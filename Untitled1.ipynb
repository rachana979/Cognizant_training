# %%
name="rachana"
print(name)
# Out:
# rachana

# %%
name="rachana"
email="rachanakada24@email.com"
print(name)
print(email)
# Out:
# rachana
# rachanakada24@email.com

# %%
city="japan"
print(city[3])
# Out:
# a

# %%
city="bihar"
print(city[-5])
# Out:
# b

# %%
city="mumbai"
print(city[1:3])
# Out:
# um

# %%
name="rachana"
print(name[1:5])
# Out:
# acha

# %%
print(len(name))
# Out:
# 7

# %%
name="rachana"
last="kada"
print(name+last)
# Out:
# rachanakada

# %%
print(name,last)
# Out:
# rachana kada

# %%
print(name+"  "+last)
# Out:
# rachana  kada

# %%
print("Hellow" * 6)
# Out:
# HellowHellowHellowHellowHellowHellow
