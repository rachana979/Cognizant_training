# %%
import numpy as np
sales=np.array([120,130,240,350,560,170])
products=np.array(["A","B","C","D","E","F"])
print(sales[sales>200])
# Out:
# [240 350 560]

# %%
sales=np.average([120,340,560,230])
print(sales)
# Out:
# 312.5

# %%
sales=np.array([120,230,340,450,660])
print(np.sort(sales))
# Out:
# [120 230 340 450 660]

# %%
import numpy as np
products=np.vstack(["A","B","C","D","E"])
print(products)
# Out:
# [['A']
#  ['B']
#  ['C']
#  ['D']
#  ['E']]

# %%
products=np.hstack(["A","B","C","D","E"])
print(products)
# Out:
# ['A' 'B' 'C' 'D' 'E']
