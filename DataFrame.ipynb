# %%
import pandas as pd
data={
    "Name":['aeinnu','yeinuu','ayan'],
    "Age":[20,19,18],
    "City":['alp','knr','mtply']
}
details=pd.DataFrame(data)
print(details)
# Out:
#      Name  Age   City
# 0  aeinnu   20    alp
# 1  yeinuu   19    knr
# 2    ayan   18  mtply

# %%
import pandas as pd
data={
    "Name":['aeinnu','yeinuu','ayan'],
    "Age":[20,19,18],
    "City":['alp','knr','mtply']
}
details=pd.DataFrame(data)
print(details.shape)
# Out:
# (3, 3)

# %%
import pandas as pd
data={
    "Name":['aeinnu','yeinuu','ayan'],
    "Age":[20,19,18],
    "City":['alp','knr','mtply']
}
details=pd.DataFrame(data)
print(details.columns)
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')

# %%
import pandas as pd
data={
    "Name":['aeinnu','yeinuu','ayan'],
    "Age":[20,19,18],
    "City":['alp','knr','mtply']
}
details=pd.DataFrame(data)
print(details.index)
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
import pandas as pd
data={
    "Name":['aeinnu','yeinuu','ayan'],
    "Age":[20,19,18],
    "City":['alp','knr','mtply']
}
details=pd.DataFrame(data)
print(details.head())
# Out:
#      Name  Age   City
# 0  aeinnu   20    alp
# 1  yeinuu   19    knr
# 2    ayan   18  mtply

# %%
import pandas as pd
data={
    "Name":['aeinnu','yeinuu','ayan'],
    "Age":[20,19,18],
    "City":['alp','knr','mtply']
}
details=pd.DataFrame(data)
print(details.tail())
# Out:
#      Name  Age   City
# 0  aeinnu   20    alp
# 1  yeinuu   19    knr
# 2    ayan   18  mtply

# %%
import pandas as pd
data={
    "Name":['aeinnu','yeinuu','ayan'],
    "Age":[20,19,18],
    "City":['alp','knr','mtply']
}
details=pd.DataFrame(data)
print(details.sample(3))
# Out:
#      Name  Age   City
# 1  yeinuu   19    knr
# 2    ayan   18  mtply
# 0  aeinnu   20    alp

# %%
import pandas as pd
data={
    "Name":['aeinnu','yeinuu','ayan'],
    "Age":[20,19,18],
    "City":['alp','knr','mtply']
}
details=pd.DataFrame(data)
print(details.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   City    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes
# None

# %%
import pandas as pd
data={
    "Name":['aeinnu','yeinuu','ayan'],
    "Age":[20,19,18],
    "City":['alp','knr','mtply']
}
details=pd.DataFrame(data)
print(details.describe())
# Out:
#         Age
# count   3.0
# mean   19.0
# std     1.0
# min    18.0
# 25%    18.5
# 50%    19.0
# 75%    19.5
# max    20.0

# %%
import pandas as pd
data={
    "Name":['aeinnu','yeinuu','ayan'],
    "Age":[20,19,18],
    "City":['alp','knr','mtply']
}
details=pd.DataFrame(data)
print(details["Name"])
# Out:
# 0    aeinnu
# 1    yeinuu
# 2      ayan
# Name: Name, dtype: object

# %%
import pandas as pd
data={
    "Name":['aeinnu','yeinuu','ayan'],
    "Age":[20,19,18],
    "City":['alp','knr','mtply']
}
details=pd.DataFrame(data)
print(details["Age"])
# Out:
# 0    20
# 1    19
# 2    18
# Name: Age, dtype: int64

# %%
import pandas as pd
data={
    "Name":['aeinnu','yeinuu','ayan'],
    "Age":[20,19,18],
    "City":['alp','knr','mtply']
}
details=pd.DataFrame(data)
print(details["City"])
# Out:
# 0      alp
# 1      knr
# 2    mtply
# Name: City, dtype: object

# %%
import pandas as pd
data={
    "Name":['aeinnu','yeinuu','ayan'],
    "Age":[20,19,18],
    "City":['alp','knr','mtply']
}
details=pd.DataFrame(data)
print(details.loc[0])
# Out:
# Name    aeinnu
# Age         20
# City       alp
# Name: 0, dtype: object

# %%
import pandas as pd
data={
    "Name":['aeinnu','yeinuu','ayan'],
    "Age":[20,19,18],
    "City":['alp','knr','mtply']
}
details=pd.DataFrame(data)
print(details.loc[[0,2]])
# Out:
#      Name  Age   City
# 0  aeinnu   20    alp
# 2    ayan   18  mtply

# %%
import pandas as pd
data={
    "Name":['aeinnu','yeinuu','ayan'],
    "Age":[20,19,18],
    "City":['alp','knr','mtply']
}
details=pd.DataFrame(data)
print(details.Age>18)
# Out:
# 0     True
# 1     True
# 2    False
# Name: Age, dtype: bool

# %%
import pandas as pd
data={
    "Name":['aeinnu','yeinuu','ayan'],
    "Age":[20,19,18],
    "City":['alp','knr','mtply']
}
details=pd.DataFrame(data)
print(details.[details.Age>18]),([details["Age"]<19])
details['Grade']=['A','B,''C']
# Out:
#   Cell In[18], line 8
#     print(details.[details.Age>18]),([details["Age"]<19])
#                   ^
# SyntaxError: invalid syntax
