# %%
import matplotlib.pyplot as plt
products=["Mobile","Laptop","Tablet"]
sales=[500,400,300]
plt.bar(products,sales)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
student=["vasrhu","vyshu","sam","vaini","youini"]
marks=[25,40,20,50,30]
plt.bar(student,marks)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
student=["varsh","vysh","siri"]
marks=[30,40,50]
plt.barh(student,marks)
plt.show()

# %%
import numpy as np
products=["mobile","laptop","tablet"]
sales_2024=[500,400,300]
sales_2025=[400,300,200]
x=np.arange(len(products))
width=0.35
plt.bar(x-width/2,sales_2024,width)
plt.bar(x-width/2,sales_2025,width)
# Out:
# <BarContainer object of 3 artists>

# %%
products=["mobile","tab","laptop","computer"]
online=[200,300,400,500]
offline=[100,200,400,600]
plt.bar(products,online)
plt.bar(products,offline,bottom=online)
plt.show()

# %%
student=["rachna","moksh","vyshh","hardsthaw"]
test1=[10,20,30,40]
test2=[50,60,70,80]
plt.bar(student,test1)
plt.bar(student,test2,bottom=test1)
plt.show()

# %%
customers=list(range(1,100))
k=10
sample=customers[::k]
print("Systematics sample",sample)
# Out:
# Systematics sample [1, 11, 21, 31, 41, 51, 61, 71, 81, 91]

# %%
import random
developer=list(range(1,56))
tester=list(range(410,610))
manager=list(range(710,910))
sample_dev=random.sample(developer,5)
sample_test=random.sample(tester,3)
sample_mrg=random.sample(manager,2)
final_sample=sample_dev+sample_test+sample_mrg
print(final_sample)
# Out:
# [35, 4, 47, 40, 19, 601, 590, 511, 736, 873]
